# %%
from sensor_core import SensorManager
from sensor_core.serial import ser_manager
import numpy as np
from itertools import product
# Out:
# ---------------------------------------
# ModuleNotFoundErrorTraceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import SensorManager
#       2 from sensor_core.serial import ser_manager
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'SensorManager'
