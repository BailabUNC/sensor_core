# %% [markdown]
# # Live line data from a simulated sensor
# This notebook acquires three channels from a simulated sensor, plots them live, stores them in SQLite, and reads the stored data back. It needs the notebook extras: `pip install "sensor-pipeline[notebook]"`. [`virtual_serial_port_line.py`](virtual_serial_port_line.py) does the same without the plot, for machines without a display.

# %%
import itertools
import time

import numpy as np

from sensor_core import SensorManager
from sensor_core.memory.strg_manager import StorageManager

# %% [markdown]
# ## Settings

# %%
CHANNELS = ["red", "infrared", "violet"]  # names of the sensor's channels
PLOT_LAYOUT = [["red", "infrared", "violet"]]  # one subplot per channel; any subset or arrangement works
NUM_POINTS = 1000  # samples shown per channel in the plot
WINDOW = 10  # samples delivered per acquisition
SAMPLE_RATE = 500  # samples per second on each channel
DATABASE = "virtual_serial_port_line.sqlite3"  # where acquired data is stored

# %% [markdown]
# ## Acquisition function
# sensor_core calls this function over and over, passing the serial port (`ser`, which is `None` for a virtual port) and `frame_shape = (num_points, window_size, channels)`. Each call returns one acquisition, an array shaped `(window_size, channels)`, or `None` if nothing new is available. This one simulates a sensor that sends a sine wave on each channel.

# %%
FREQUENCIES = [1.0, 2.0, 3.0]  # Hz, one sine wave per channel
next_sample = itertools.count(step=WINDOW)


def acquire_data(ser, frame_shape):
    time.sleep(WINDOW / SAMPLE_RATE)  # as long as the sensor takes to produce WINDOW samples
    t = (next(next_sample) + np.arange(WINDOW)) / SAMPLE_RATE
    signal = np.stack([100*np.sin(2 * np.pi * f * t) for f in FREQUENCIES], axis=1)
    return signal.astype(np.float32)

# %% [markdown]
# ## Start acquiring and storing
# `start_stream_ingest=True` stores everything acquired in `DATABASE`. Acquisition runs in its own process (a thread on Windows) until the SensorManager is closed. If you run this cell again, the previous SensorManager for the same database is closed first.

# %%
sm = SensorManager(ser_channel_key=CHANNELS,
                   plot_channel_key=PLOT_LAYOUT,
                   commport=None,
                   frame_shape=(NUM_POINTS, WINDOW, len(CHANNELS)),  # (num_points, window_size, channels)
                   start_stream_ingest=True,
                   sqlite_path=DATABASE)
acquisition = sm.update_data_process(virtual_ser_port=True, func=acquire_data)
sm.start_process(acquisition)

# %% [markdown]
# ## Plot live
# The figure updates itself while it is shown. Start acquisition before creating the plot: on Linux and macOS, worker processes are started by forking this kernel, which is safest before the plot initializes the GPU.

# %%
plot = sm.create_plot()
plot.show()

# %% [markdown]
# ## Check what was stored
# `flush()` waits until everything acquired so far is in the database, while acquisition keeps running. Each acquisition is stored as one frame, together with the time it was acquired.

# %%
time.sleep(2)  # let some data accumulate
sm.flush()

red = StorageManager.load_serial_channel("red", DATABASE, session=-1)  # session=-1: this run only
times = StorageManager.load_frame_times(DATABASE, session=-1)  # ns since the Unix epoch
print(f"{len(times)} acquisitions stored: {len(red)} samples per channel")
print(f"one timestamp per {len(red) // len(times)} samples; times increase: {bool(np.all(np.diff(times) > 0))}")

# %% [markdown]
# ## Metrics

# %%
metrics = sm.get_metrics()
{
    "frames written": metrics["writer"].get("writer_total_frames"),
    "frames dropped": metrics["writer"].get("writer_dropped_frames"),
    "frames stored": metrics["ingest"].get("ingest_frames_ingested"),
}

# %% [markdown]
# ## Clean up
# `close()` stops acquisition, stores everything acquired, and releases the shared memory. In a script, `with SensorManager(...) as sm:` does this automatically.

# %%
sm.close()
print(f"{StorageManager.list_sessions(DATABASE)[-1]['frames']} acquisitions stored in total")
