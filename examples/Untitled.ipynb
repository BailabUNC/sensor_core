# %%
from sensor_core import SensorManager
import numpy as np

# %%
ser_channel_key = ["cam0"]                    # Names of serial channels
plot_channel_key = [["cam0"]]                 # Names and gridplot arrangement of plot channels
commport = None                               # Name of comm port
baudrate = None

# %%
# Custom Serial Acquisition Function
def acquire_data(ser, frame_shape):
    """ serial acquisition function handler. All parameters are internally generated
    Must include the following parameters:
    :param ser: serial port
    :param window_size: number of frames to capture before passing to shared memory object. Default 1
    :param num_channel: number of channels to capture. 
    """
    channel_data = np.random.rand(frame_shape[0], frame_shape[1], 1)*255
    channel_data = channel_data.astype(np.uint8)
    return channel_data

# %%
# Instantiate Sensor Manager class
sm = SensorManager(ser_channel_key=ser_channel_key,
                   plot_channel_key=plot_channel_key,
           # Create 'update process' to handle acquired data
update_process = sm.update_data_process(save_data=True, 
                            filepath='./serial_db.sqlite3',
                            virtual_ser_port = True,
                            func=acquire_data)
# Create 'plot process' to handle plotting. Returns plot object as well
plot_process, plot = sm.setup_plotting_process()       commport=commport, 
                   baudrate=baudrate,
                   dtype=np.uint8,
                   data_mode='image',
                   frame_shape=(640,480,1),    # Width, Height, num_channels
                   rotate_frames=256,
                   start_stream_ingest=True)

# %%
# Create 'update process' to handle acquired data
update_process = sm.update_data_process(save_data=True, 
                            filepath='./serial_db.sqlite3',
                            virtual_ser_port = True,
                            func=acquire_data)

# %%
stuff = sm.get_metrics()
print(stuff)
# Out:
# {'writer': {'init': True, 'writer_alive': True, 'writer_start_unix': 1770302403.9939363, 'writer_watch_bins': ['C:\\Users\\lukep\\Downloads\\sensor_core2\\sensor_core\\examples\\serial_stream_a.bin', 'C:\\Users\\lukep\\Downloads\\sensor_core2\\sensor_core\\examples\\serial_stream_b.bin'], 'writer_watch_seals': ['C:\\Users\\lukep\\Downloads\\sensor_core2\\sensor_core\\examples\\serial_stream_a.bin.seal', 'C:\\Users\\lukep\\Downloads\\sensor_core2\\sensor_core\\examples\\serial_stream_b.bin.seal'], 'writer_ring': {'name': '/sensor_ring', 'capacity': 4096, 'shape': (640, 480, 1), 'dtype': 'uint8'}, 'writer_active_bin': 'C:\\Users\\lukep\\Downloads\\sensor_core2\\sensor_core\\examples\\serial_stream_b.bin', 'writer_total_frames': 0, 'writer_total_bytes': 0, 'writer_rotations': 53, 'writer_fps_estimate': 0.0, 'writer_last_rotation_unix': 1770302669.4671214, 'writer_updated_unix': 1770302670.4701872, 'writer_seal_exists': [False, False], 'writer_seal_mtime': [None, None]}, 'plot': {'init': True}, 'ingest': {'init': True, 'ingest_config_enabled': True, 'ingest_config_reason': 'explicit_flag', 'ingest_bins_ingested': 53, 'ingest_frames_ingested': 0, 'ingest_bytes_read': 0, 'ingest_batches_flushed': 0, 'ingest_fps_estimate': 0.0, 'ingest_updated_unix': 1770302670.516403, 'ingest_alive': True, 'ingest_watch_paths': ['C:\\Users\\lukep\\Downloads\\sensor_core2\\sensor_core\\examples\\serial_stream_a.bin', 'C:\\Users\\lukep\\Downloads\\sensor_core2\\sensor_core\\examples\\serial_stream_b.bin'], 'ingest_sqlite_path': 'C:\\Users\\lukep\\Downloads\\sensor_core2\\sensor_core\\examples\\serial_db.sqlite3', 'ingest_started': True, 'ingest_starting': False, 'ingest_scan_seals': ['C:\\Users\\lukep\\Downloads\\sensor_core2\\sensor_core\\examples\\serial_stream_a.bin.seal', 'C:\\Users\\lukep\\Downloads\\sensor_core2\\sensor_core\\examples\\serial_stream_b.bin.seal'], 'ingest_scan_exists': [False, False], 'ingest_scan_mtime': [None, None], 'ingest_last_header': {'path': 'C:\\Users\\lukep\\Downloads\\sensor_core2\\sensor_core\\examples\\serial_stream_a.bin', 'data_mode': 'image', 'frame_shape': (640, 480, 1), 'dtype': 'uint8'}}}
